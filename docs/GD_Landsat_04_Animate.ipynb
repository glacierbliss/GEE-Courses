# %% [markdown]
# OBSOLETE: See GD_Landsat_04_Animate.py, not ipynb
# GD_Landsat_04_Animate takes results from GD_Landsat_03_Select and animates them using ffmpeg

# %%
import

# %%
#filter out images that are close in time. 
#favor a single path/row if possible (McBride elevation change means georegistration not always great)
#get coordinates of image corners, with projection - use an actual projection, or just approximate? high accuracy probably not needed
#add outlines, color by date
#rainbow progress bar, matching colors with dates


#may need to weed out odd sizes - with this method, if image only 
#covers part of bounding box, rescaled image may be taller than expected
#scale bar
